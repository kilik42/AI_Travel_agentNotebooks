# %%
#get our database url
# create db engine via sqlalchemy

# %%
from env import config, BASE_DIR
from sqlalchemy import create_engine, text

# %%
DATABASE_URL = config("FLIGHT_PRICES_DATABASE_URL", cast=str, default=None)

# %%
DATABASE_URL is not None
# Out:
# True

# %%
engine = create_engine(DATABASE_URL)

# %%
DATASET_DIR = BASE_DIR / "datasets"
DATASET_DIR.exists()
# Out:
# True

# %%
FLIGHT_PRICES_CSV = DATASET_DIR / "itineraries-min-50k.csv"
FLIGHT_PRICES_CSV.exists()
# Out:
# True

# %%
import pandas as pd

# %%
df = pd.read_csv(str(FLIGHT_PRICES_CSV))
df.head(n=10)
# Out:
#                               legId  searchDate  flightDate startingAirport  \
# 0  9ca0e81111c683bec1012473feefd28f  2022-04-16  2022-04-17             ATL
# 1  98685953630e772a098941b71906592b  2022-04-16  2022-04-17             ATL
# 2  98d90cbc32bfbb05c2fc32897c7c1087  2022-04-16  2022-04-17             ATL
# 3  969a269d38eae583f455486fa90877b4  2022-04-16  2022-04-17             ATL
# 4  980370cf27c89b40d2833a1d5afc9751  2022-04-16  2022-04-17             ATL
# 5  79eda9f841e226a1e2121d74211e595c  2022-04-16  2022-04-17             ATL
# 6  9335fae376c38bb61263281779f469ec  2022-04-16  2022-04-17             ATL
# 7  3904bf87f2d1daf334f1ae7e3b876028  2022-04-16  2022-04-17             ATL
# 8  d93988734c44a3c075d9efe373352507  2022-04-16  2022-04-17             ATL
# 9  562e7d5dd6ecbf1509c0c19711dbdca9  2022-04-16  2022-04-17             ATL
#
#   destinationAirport fareBasisCode travelDuration  elapsedDays  \
# 0                BOS      LA0NX0MC        PT2H29M          0.0
# 1                BOS      LA0NX0MC        PT2H30M          0.0
# 2                BOS      LA0NX0MC        PT2H30M          0.0
# 3                BOS      LA0NX0MC        PT2H32M          0.0
# 4                BOS      LA0NX0MC        PT2H34M          0.0
# 5                BOS      VH0AUEL1        PT2H38M          0.0
# 6                BOS      V0AJZNN1        PT4H12M          0.0
# 7                BOS      V0AJZNN1        PT5H18M          0.0
# 8                BOS      V0AJZNN1        PT5H32M          0.0
# 9                BOS      V0AJZNN1        PT6H38M          0.0
#
#    isBasicEconomy  isRefundable  ...  segmentsArrivalTimeEpochSeconds  \
# 0           False         False  ...                       1650223560
# 1           False         False  ...                       1650200400
# 2           False         False  ...                       1650218700
# 3           False         False  ...                       1650227460
# 4           False         False  ...                       1650213180
# 5           False         False  ...                       1650216180
# 6           False         False  ...           1650203400||1650213120
# 7           False         False  ...           1650203400||1650217080
# 8           False         False  ...           1650198060||1650213120
# 9           False         False  ...           1650198060||1650217080
#
#                               segmentsArrivalTimeRaw  \
# 0                      2022-04-17T15:26:00.000-04:00
# 1                      2022-04-17T09:00:00.000-04:00
# 2                      2022-04-17T14:05:00.000-04:00
# 3                      2022-04-17T16:31:00.000-04:00
# 4                      2022-04-17T12:33:00.000-04:00
# 5                      2022-04-17T13:23:00.000-04:00
# 6  2022-04-17T09:50:00.000-04:00||2022-04-17T12:3...
# 7  2022-04-17T09:50:00.000-04:00||2022-04-17T13:3...
# 8  2022-04-17T08:21:00.000-04:00||2022-04-17T12:3...
# 9  2022-04-17T08:21:00.000-04:00||2022-04-17T13:3...
#
#    segmentsArrivalAirportCode  segmentsDepartureAirportCode  \
# 0                         BOS                           ATL
# 1                         BOS                           ATL
# 2                         BOS                           ATL
# 3                         BOS                           ATL
# 4                         BOS                           ATL
# 5                         BOS                           ATL
# 6                    CLT||BOS                      ATL||CLT
# 7                    CLT||BOS                      ATL||CLT
# 8                    CLT||BOS                      ATL||CLT
# 9                    CLT||BOS                      ATL||CLT
#
#                     segmentsAirlineName segmentsAirlineCode  \
# 0                                 Delta                  DL
# 1                                 Delta                  DL
# 2                                 Delta                  DL
# 3                                 Delta                  DL
# 4                                 Delta                  DL
# 5                       JetBlue Airways                  B6
# 6  American Airlines||American Airlines              AA||AA
# 7  American Airlines||American Airlines              AA||AA
# 8  American Airlines||American Airlines              AA||AA
# 9  American Airlines||American Airlines              AA||AA
#
#   segmentsEquipmentDescription segmentsDurationInSeconds segmentsDistance  \
# 0                  Airbus A321                      8940              947
# 1                  Airbus A321                      9000              947
# 2               Boeing 757-200                      9000              947
# 3                  Airbus A321                      9120              947
# 4                  Airbus A321                      9240              947
# 5                          NaN                      9480              947
# 6     Airbus A320||Airbus A320                5400||7500         228||728
# 7  Airbus A320||Boeing 737-800                5400||8280         228||728
# 8     Airbus A319||Airbus A320                4860||7500         228||728
# 9  Airbus A319||Boeing 737-800                4860||8280         228||728
#
#   segmentsCabinCode
# 0             coach
# 1             coach
# 2             coach
# 3             coach
# 4             coach
# 5             coach
# 6      coach||coach
# 7      coach||coach
# 8      coach||coach
# 9      coach||coach
#
# [10 rows x 27 columns]

# %%
df.dtypes
# Out:
# legId                                 object
# searchDate                            object
# flightDate                            object
# startingAirport                       object
# destinationAirport                    object
# fareBasisCode                         object
# travelDuration                        object
# elapsedDays                          float64
# isBasicEconomy                          bool
# isRefundable                            bool
# isNonStop                               bool
# baseFare                             float64
# totalFare                            float64
# seatsRemaining                       float64
# totalTravelDistance                  float64
# segmentsDepartureTimeEpochSeconds     object
# segmentsDepartureTimeRaw              object
# segmentsArrivalTimeEpochSeconds       object
# segmentsArrivalTimeRaw                object
# segmentsArrivalAirportCode            object
# segmentsDepartureAirportCode          object
# segmentsAirlineName                   object
# segmentsAirlineCode                   object
# segmentsEquipmentDescription          object
# segmentsDurationInSeconds             object
# segmentsDistance                      object
# segmentsCabinCode                     object
# dtype: object

# %%
#df['date'] = pd.to_datetime(df['saledate'], format="%d/%m/%Y")
#$df['price'] = df['MA']

# %%
#df.dtypes

# %%
out_df = df.copy()#[['date', 'price','type', 'bedrooms']]
out_df
# Out:
#                                   legId  searchDate  flightDate  \
# 0      9ca0e81111c683bec1012473feefd28f  2022-04-16  2022-04-17
# 1      98685953630e772a098941b71906592b  2022-04-16  2022-04-17
# 2      98d90cbc32bfbb05c2fc32897c7c1087  2022-04-16  2022-04-17
# 3      969a269d38eae583f455486fa90877b4  2022-04-16  2022-04-17
# 4      980370cf27c89b40d2833a1d5afc9751  2022-04-16  2022-04-17
# ...                                 ...         ...         ...
# 49995  e30daf27fb475125ff172d9aec92c3ae  2022-04-16  2022-04-22
# 49996  ddb2252f70f192ba812e3e91220ea72c  2022-04-16  2022-04-22
# 49997  400e77c692f8e7dca6bca3c68db2d52a  2022-04-16  2022-04-22
# 49998  a8ea5bb8580b4eddd3ea2c0958ed45bb  2022-04-16  2022-04-22
# 49999  fded33975980f2fc8c32483775f60447  2022-04-16  2022-04-22
#
#       startingAirport destinationAirport fareBasisCode travelDuration  \
# 0                 ATL                BOS      LA0NX0MC        PT2H29M
# 1                 ATL                BOS      LA0NX0MC        PT2H30M
# 2                 ATL                BOS      LA0NX0MC        PT2H30M
# 3                 ATL                BOS      LA0NX0MC        PT2H32M
# 4                 ATL                BOS      LA0NX0MC        PT2H34M
# ...               ...                ...           ...            ...
# 49995             IAD                LAX      SAA3PQBN        PT7H44M
# 49996             IAD                LAX      G3AZZNN1         PT8H1M
# 49997             IAD                LAX      G3AZZNN1        PT9H25M
# 49998             IAD                LAX      G3AZZNN1       PT10H23M
# 49999             IAD                LAX      G3AZZNN1       PT10H27M
#
#        elapsedDays  isBasicEconomy  isRefundable  ...  \
# 0              0.0           False         False  ...
# 1              0.0           False         False  ...
# 2              0.0           False         False  ...
# 3              0.0           False         False  ...
# 4              0.0           False         False  ...
# ...            ...             ...           ...  ...
# 49995          0.0            True         False  ...
# 49996          0.0           False         False  ...
# 49997          0.0           False         False  ...
# 49998          0.0           False         False  ...
# 49999          0.0           False         False  ...
#
#        segmentsArrivalTimeEpochSeconds  \
# 0                           1650223560
# 1                           1650200400
# 2                           1650218700
# 3                           1650227460
# 4                           1650213180
# ...                                ...
# 49995           1650631740||1650652140
# 49996           1650667620||1650684660
# 49997           1650639000||1650660180
# 49998           1650639000||1650663660
# 49999           1650667620||1650693420
#
#                                   segmentsArrivalTimeRaw  \
# 0                          2022-04-17T15:26:00.000-04:00
# 1                          2022-04-17T09:00:00.000-04:00
# 2                          2022-04-17T14:05:00.000-04:00
# 3                          2022-04-17T16:31:00.000-04:00
# 4                          2022-04-17T12:33:00.000-04:00
# ...                                                  ...
# 49995  2022-04-22T07:49:00.000-05:00||2022-04-22T11:2...
# 49996  2022-04-22T17:47:00.000-05:00||2022-04-22T20:3...
# 49997  2022-04-22T09:50:00.000-05:00||2022-04-22T13:4...
# 49998  2022-04-22T09:50:00.000-05:00||2022-04-22T14:4...
# 49999  2022-04-22T17:47:00.000-05:00||2022-04-22T22:5...
#
#        segmentsArrivalAirportCode  segmentsDepartureAirportCode  \
# 0                             BOS                           ATL
# 1                             BOS                           ATL
# 2                             BOS                           ATL
# 3                             BOS                           ATL
# 4                             BOS                           ATL
# ...                           ...                           ...
# 49995                    ORD||LAX                      IAD||ORD
# 49996                    DFW||LAX                      IAD||DFW
# 49997                    DFW||LAX                      IAD||DFW
# 49998                    DFW||LAX                      IAD||DFW
# 49999                    DFW||LAX                      IAD||DFW
#
#                         segmentsAirlineName segmentsAirlineCode  \
# 0                                     Delta                  DL
# 1                                     Delta                  DL
# 2                                     Delta                  DL
# 3                                     Delta                  DL
# 4                                     Delta                  DL
# ...                                     ...                 ...
# 49995                        United||United              UA||UA
# 49996  American Airlines||American Airlines              AA||AA
# 49997  American Airlines||American Airlines              AA||AA
# 49998  American Airlines||American Airlines              AA||AA
# 49999  American Airlines||American Airlines              AA||AA
#
#        segmentsEquipmentDescription segmentsDurationInSeconds  \
# 0                       Airbus A321                      8940
# 1                       Airbus A321                      9000
# 2                    Boeing 757-200                      9000
# 3                       Airbus A321                      9120
# 4                       Airbus A321                      9240
# ...                             ...                       ...
# 49995   Airbus A320||Boeing 737-800               7440||16560
# 49996  Boeing 737-800||BOEING 787-9              11820||11760
# 49997   Boeing 737-800||Airbus A321              12720||12060
# 49998   Boeing 737-800||Airbus A321              12720||12060
# 49999   Boeing 737-800||Airbus A321              11820||12120
#
#       segmentsDistance segmentsCabinCode
# 0                  947             coach
# 1                  947             coach
# 2                  947             coach
# 3                  947             coach
# 4                  947             coach
# ...                ...               ...
# 49995        594||1745      coach||coach
# 49996       1177||1238      coach||coach
# 49997       1177||1238      coach||coach
# 49998       1177||1238      coach||coach
# 49999       1177||1238      coach||coach
#
# [50000 rows x 27 columns]

# %%
table_name = "flight_prices"
df.to_sql(table_name, engine, if_exists='replace', index=False)
# Out:
# 50000

# %%
with engine.connect() as conn:
    results = conn.execute(text(f"SELECT * from {table_name} LIMIT 10"))
    print(results.all())
# Out:
# [('9ca0e81111c683bec1012473feefd28f', '2022-04-16', '2022-04-17', 'ATL', 'BOS', 'LA0NX0MC', 'PT2H29M', 0.0, 0, 0, 1, 217.67, 248.6, 9.0, 947.0, '1650214620', '2022-04-17T12:57:00.000-04:00', '1650223560', '2022-04-17T15:26:00.000-04:00', 'BOS', 'ATL', 'Delta', 'DL', 'Airbus A321', '8940', '947', 'coach'), ('98685953630e772a098941b71906592b', '2022-04-16', '2022-04-17', 'ATL', 'BOS', 'LA0NX0MC', 'PT2H30M', 0.0, 0, 0, 1, 217.67, 248.6, 4.0, 947.0, '1650191400', '2022-04-17T06:30:00.000-04:00', '1650200400', '2022-04-17T09:00:00.000-04:00', 'BOS', 'ATL', 'Delta', 'DL', 'Airbus A321', '9000', '947', 'coach'), ('98d90cbc32bfbb05c2fc32897c7c1087', '2022-04-16', '2022-04-17', 'ATL', 'BOS', 'LA0NX0MC', 'PT2H30M', 0.0, 0, 0, 1, 217.67, 248.6, 9.0, 947.0, '1650209700', '2022-04-17T11:35:00.000-04:00', '1650218700', '2022-04-17T14:05:00.000-04:00', 'BOS', 'ATL', 'Delta', 'DL', 'Boeing 757-200', '9000', '947', 'coach'), ('969a269d38eae583f455486fa90877b4', '2022-04-16', '2022-04-17', 'ATL', 'BOS', 'LA0NX0MC', 'PT2H32M', 0.0, 0, 0, 1, 217.67, 248.6, 8.0, 947.0, '1650218340', '2022-04-17T13:59:00.000-04:00', '1650227460', '2022-04-17T16:31:00.000-04:00', 'BOS', 'ATL', 'Delta', 'DL', 'Airbus A321', '9120', '947', 'coach'